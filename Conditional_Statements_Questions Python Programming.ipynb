# %%
# check if a number is positive or nagetive.
num = int(input("Enter a number"))
if num > 0:
    print(f'{num} is Positive')
else:
    print(f'{num} is Negative')
# Out:
# Enter a number -5
# -5 is Negative

# %%
# ckech if a number is even or odd.
num = int(input("Enter a num ="))
if num%2==0:
    print(f'Even = {num}')
else:
    print(f'Odd = {num}')
# Out:
# Enter a num 2
# Even = 2

# %%
# ckeck if a person is eligible to vote (age>=18).
age = int(input("enter a number ="))
if age >=18:
    print("Person is eligible to vote")
else:
    print("Person is not eligible to vote")
# Out:
# enter a number = 19
# Person is eligible to vote

# %%
# find the greatest of two numbers.
a = int(input("Enter the first number"))
b = int(input("Enter the second number"))
if a > b:
    print(f"{a}  is  Greatest {b}")
else:
    print(f"{a} is Not Greatest {b}")
# Out:
# Enter the first number 5
# Enter the second number 4
# 5  is  Greatest 4

# %%
# check if a number is divisible by 5.
num = int(input("Enter a number"))
if num%5==0:
    print("Number isDivisible by 5")
else:
    print("Number is Not Divisible by 5")
# Out:
# Enter a number 25
# Number isDivisible by 5

# %%
# check if a number is within a range (20 to 60)
num = int(input("enter a number"))
if 20 <= num <=60:
    print(f'{num} = is within the range (20 to 60).')
else:
    print(f'{num} = is not within range (20 to 60).')
# Out:
# enter a number 25
# 25 = is within the range (20 to 60).

# %%
# check if a number is multiple of both 5 and 9.
num = int(input("enter a number"))
if num%5==0 and num%9==0:
    print(f"{num} is multiple of both 5 and 9")
else:
    print(f"{num} Number is not multiple of both 5 and 9")
# Out:
# enter a number 45
# 45 is multiple of both 5 and 9

# %%
# Check if a day weekday or weekend.
day = input("Enter a day name")
weekend = "Saturday","Sunday"
if day in weekend:
    print("Weekend")
else:
    print("Weekday")
# Out:
# enter a day name Saturday
# Weekend

# %%
# chech the greatest value in three numbers who is the greatest number.
num1 = int(input("Enter a first number"))
num2 = int(input("Enter a second number"))
num3 = int(input("Enter a third number"))
if num1 > num2 and num1 > num3:
    print(f' {num1} = is greatest')
elif num2 > num3 and num2 > num1:
    print(f' {num2} = is greatest')
else:
    print(f' {num3} = is greatest')
# Out:
# Enter a first number 5
# Enter a second number 2
# Enter a third number 4
#  5 = is greatest

# %%
# Take two numbers as input from the user and display their sum, difference, product, and division.
num1 = float(input("Enter first number:"))
operation = input("Enter the operation")
num2 = float(input("Enter second number:"))
w = num1 + num2
x = num1 - num2
y = num1 * num2
z= num1 / num2
if operation == "+":
    print(f"Sum: {num1} + {num2} = {w}")
elif operation == "-":
    print(f"Difference: {num1} - {num2} = {x}")
elif operation == "*":
    print(f"Product: {num1} * {num2} = {y}")
else :
    print(f"Division: {num1} / {num2} = {z}")
# Out:
# Enter first number: 5
# Enter the operation /
# Enter second number: 2
# Division: 5.0 / 2.0 = 2.5
